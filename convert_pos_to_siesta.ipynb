# %%
dat = []
with open('lic12.pos') as f:
    for i, line in enumerate(f):
        el = ' 1'
        if i > 17:
            el = ' 2'
        dat.append(line.strip() + el)

# %%
dat[0]
# Out:
# '0.02035497  0.01071900  0.01133787 1'

# %%
dat = []
with open('lic12.pos') as f:
    for i, line in enumerate(f):
        el = 'Li    '
        if i > 17:
            el = ' C    '
        dat.append(el + line.strip())

with open('lic12.xyz', 'w') as f:
    for line in dat:
        f.write(f"{line}\n")

# %%
cfg_file = 'high_eng.cfg'
size = 0
lines = []

with open(cfg_file) as f:
    for i, line in enumerate(f):
        if "Size" in line:
            size = int(f[i + 1])
        if len(line.strip().split()) == 8:
            lines.append(line)
        c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_650/1812482723.py in <module>
#       6     for i, line in enumerate(f):
#       7         if "Size" in line:
# ----> 8             size = int(f[i + 1])
#       9         if len(line.strip().split()) == 8:
#      10             lines.append(line)
#
# TypeError: '_io.TextIOWrapper' object is not subscriptable

# %%
cfg_file = 'high_eng.cfg'
size = 0
dat = []

with open(cfg_file) as f:
    dat = f.readlines()
    
atoms = []
for line in dat:
    if "Size" in line:
            size = int(dat[i + 1])
    line_clean = line.strip().split()
    if len(line_clean) == 8:
        atoms.append(line_clean)
      
if len(atoms) != size:
    print("There seems to be a problem")

# %%
len(lines)
# Out:
# 189

# %%
size
# Out:
# 189

# %%
len(lines) == size
# Out:
# True

# %%
atoms[0]
# Out:
# ['1',
#  '0',
#  '-0.000200',
#  '0.001000',
#  '-0.000200',
#  '0.001600',
#  '-0.004300',
#  '0.004700']

# %%
for at in atoms:
    print(at[2], at[3], at[4], int(at[1]) + 1)
# Out:
# -0.000200 0.001000 -0.000200 1
# -0.000200 0.001100 3.563200 1
# -0.000200 0.001000 7.121200 1
# -2.158400 3.773200 -0.000200 1
# -4.315500 7.541800 -0.000200 1
# 4.373000 7.576100 -0.000200 1
# 2.186100 3.790400 -0.000200 1
# 4.346700 0.016800 -0.000200 1
# 8.691300 0.033800 -0.000300 1
# -2.158400 3.773300 3.563200 1
# -4.315500 7.541800 7.121100 1
# 4.373000 7.576000 3.563300 1
# 2.186100 3.790500 7.121100 1
# 4.346800 0.016800 3.563200 1
# 8.691300 0.033700 7.121100 1
# -4.315500 7.541700 3.563200 1
# -2.158400 3.773200 7.121100 1
# 2.186100 3.790500 3.563200 1
# 4.372900 7.576100 7.121100 1
# 8.691200 0.033800 3.563200 1
# 4.346800 0.016800 7.121100 1
# 0.028600 7.559100 -0.000200 1
# 6.532700 3.806000 -0.000200 1
# 0.028700 7.559000 3.563200 1
# 6.532700 3.806000 7.121100 1
# 6.532700 3.806000 3.563200 1
# 0.028700 7.559100 7.121100 1
# -0.757600 1.298100 1.780800 2
# -5.716700 10.017300 8.903500 2
# 5.951800 10.308500 1.780900 2
# 0.610700 1.057000 8.903500 2
# ...
